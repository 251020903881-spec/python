# %% [markdown]
# <a href="https://colab.research.google.com/github/251020903881-spec/python/blob/main/trang%2042.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter a positive integer: "))
print(n)
s = 0
i = 0
while i < n:
    s += i
    i += 2
print(f"The sum of even numbers less than {n} is {s}")
# Out:
# Enter a positive integer: 20
# 20
# The sum of even numbers less than 20 is 90
