# %% [markdown]
# <a href="https://colab.research.google.com/github/251020903881-spec/python/blob/main/b%C3%A0i%209%20trang%2038.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    a = float(input("Nhập a: "))
    b = float(input("Nhập b: "))
    c = float(input("Nhập c: "))
except ValueError:
    print("Vui lòng nhập số thực hợp lệ.")
    exit()
if a == 0:
    if b == 0:
        if c == 0:
            print("Phương trình có vô số nghiệm.")
        else:
            print("Phương trình vô nghiệm.")
    else:
        x = -c / b
        print(f"Phương trình bậc nhất, nghiệm x = {x}")
else:
    delta = b**2 - 4*a*c

    if delta > 0:
        x1 = (-b + math.sqrt(delta)) / (2*a)
        x2 = (-b - math.sqrt(delta)) / (2*a)
        print("Phương trình có hai nghiệm phân biệt:")
        print(f"x1 = {x1}")
        print(f"x2 = {x2}")
    elif delta == 0:
        x = -b / (2*a)
        print("Phương trình có nghiệm kép:")
        print(f"x1 = x2 = {x}")
    else:
        print("Phương trình vô nghiệm thực.")
# Out:
# Nhập a: 2
# Nhập b: 3
# Nhập c: 4
# Phương trình vô nghiệm thực.
