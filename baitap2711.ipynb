# %%
day_so = [1, 5, 8, 12, 7, 3, 10]
tong_chan = 0
tong_le = 0
for x in day_so:
    if x % 2 == 0:
        tong_chan = tong_chan + x
    else:
        tong_le = tong_le + x
print("Dãy số:", day_so)        
print("Tổng các số chẵn là:", tong_chan)
print("Tổng các số lẻ là:", tong_le)
# Out:
# Dãy số: [1, 5, 8, 12, 7, 3, 10]
# Tổng các số chẵn là: 30
# Tổng các số lẻ là: 16
